# %% [markdown]
# Single line Comment

# %%
# This is a single line command
name = "John" # Assign string to variable
# TODO: Handle case when arhument is None.

# %% [markdown]
# Multiline Comment

# %%
'''
if True:
    print("Hello World!)
'''

# %%
"""
if True:
    print("Welcome Home!)
"""
