# %% [markdown]
# Calculate disk usage

# %%
server_name="webserver"
cpu_cores=4
memory_gb=8.0
disk_total_gb=500
disk_usage_gb=350

disk_usage_percentage = disk_usage_gb / disk_total_gb
summary_format = f"Server {server_name.upper()} has ({cpu_cores} CPU, {memory_gb} Memory) and {disk_usage_percentage:.2%} of Disk usage"
print(summary_format)
# Out:
# Server WEBSERVER has (4 CPU, 8.0 Memory) and 70.00% of Disk usage
